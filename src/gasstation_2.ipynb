# %% [markdown]
# 장진혁
# jinhyuk2ya@gmail.com

# %% [markdown]
# # 데이터 수집

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import StaleElementReferenceException
from tqdm.notebook import tqdm
import time

# %%
options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : '/home/jinhyuk3me/dev_ws/eda/data',
         'download.prompt_for_dwonload': False}
options.add_experimental_option('prefs', prefs)

url = "https://www.opinet.co.kr/searRgSelect.do"
driver = webdriver.Chrome(service=Service("/home/jinhyuk3me/dev_ws/eda/driver/chromedriver"), options=options)
driver.get(url)
driver.get(url)

# %% [markdown]
# ---

# %%
sido = driver.find_element(By.ID, "SIDO_NM0")
sido_elements = sido.find_elements(By.TAG_NAME, "option")
sido_names = [sido_element.get_attribute('value') for sido_element in sido_elements]
sido_names = sido_names[1:]
print(sido_names)
sido.send_keys(sido_names[0])
# Out:
# ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도', '강원특별자치도', '충청북도', '충청남도', '전북특별자치도', '전라남도', '경상북도', '경상남도', '제주특별자치도']

# %%
gu = driver.find_element(By.ID, "SIGUNGU_NM0")
gu_elements = gu.find_elements(By.TAG_NAME, "option")
gu_names = [gu_element.get_attribute('value') for gu_element in gu_elements]
gu_names = gu_names[1:]
print(gu_names)
gu.send_keys(gu_names[0])
# Out:
# ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']

# %% [markdown]
# ---

# %%
data = []
prev_name = ""

class MySameNameError(Exception):
    pass

for idx, gu_name in tqdm(enumerate(gu_names), total=len(gu_names)):
    #--------------------------------------------------
    print("\n[",gu_name,"]\n")
    driver.implicitly_wait(3)
    gu = driver.find_element(By.ID, "SIGUNGU_NM0")
    gu.send_keys(gu_name)
    WebDriverWait(driver, timeout=30).until(EC.visibility_of_element_located((By.CLASS_NAME, "tab_type2")))
    driver.refresh()
    print("-------------------------------------")
    while(True):
        try:
            button_panel = WebDriverWait(driver, timeout=30).until(EC.visibility_of_element_located((By.CLASS_NAME, "tab_type2")))
            button = button_panel.find_element(By.ID, """os_layer2""")
            button.click()
            station_count = driver.find_element(By.CLASS_NAME, "tc_spot").get_attribute("innerText")
            print(gu_name,"의 예상 주유소 수는 ", station_count,"개 입니다.")
            primitive_stations = driver.find_element(By.ID, "body1").find_elements(By.TAG_NAME, "tr")
            stations = [primitive_station.find_element(By.TAG_NAME, "a") for primitive_station in primitive_stations]
            print(gu_name, "의 실제 주유소 수는 ", len(stations), "개 입니다")
            break
        except StaleElementReferenceException :
            continue
    print("-------------------------------------")
    count = 0
    for station in stations :
        station.click()
        #------------------------------------------------------------------------
        while(True):
            try:
                WebDriverWait(driver, timeout=30).until(EC.visibility_of_element_located((By.ID, "os_nm")))
                station_name = driver.find_element(By.ID, "os_nm").get_attribute('innerText')
                if(station_name == prev_name):
                    raise MySameNameError
                else :
                    count = count+1
                    prev_name = station_name
                    print("[주유소 이름] ", station_name,"(",count,"""/""",len(stations),")") 
                    # 예시: 대성석유(주) 마곡대성주유소 ( 20 / 33 )
                break
            except StaleElementReferenceException :
                continue
            except MySameNameError : 
                # 새로운 상세 팝업이 열리지 않은채로 정보를 읽는 경우
                continue
        #------------------------------------------------------------------------
        print("- 고급휘발유 가격: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "b034_p").get_attribute('innerText'))
                primium_price = driver.find_element(By.ID, "b034_p").get_attribute('innerText')
                break
            except StaleElementReferenceException :
                continue
        #------------------------------------------------------------------------
        print("- 보통휘발유 가격: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "b027_p").get_attribute('innerText'))
                regular_price = driver.find_element(By.ID, "b027_p").get_attribute('innerText')
                break
            except StaleElementReferenceException :
                continue
        #------------------------------------------------------------------------
        print("- 경유 가격: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "d047_p").get_attribute('innerText'))
                diesel_price = driver.find_element(By.ID, "d047_p").get_attribute('innerText')
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 실내등유 가격: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "c004_p").get_attribute('innerText'))
                indoor_price = driver.find_element(By.ID, "c004_p").get_attribute('innerText')
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 전화번호: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "phn_no").get_attribute('innerText'))
                phone_number = driver.find_element(By.ID, "phn_no").get_attribute('innerText')
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 주소: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "rd_addr").get_attribute('innerText'))
                address = driver.find_element(By.ID, "rd_addr").get_attribute('innerText')
                break;
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 상호명: ", end="")
        while(True):
            try:
                print(driver.find_element(By.ID, "poll_div_nm").get_attribute('innerText'))
                brand = driver.find_element(By.ID, "poll_div_nm").get_attribute('innerText')
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 세차장: ", end="")
        while(True):
            try:
                if (driver.find_element(By.ID, "cwsh_yn").get_attribute('src') 
                   == "https://www.opinet.co.kr/images/user/gis/oil_station_service1_01.gif"):
                    car_wash = True
                    print(car_wash)
                else :
                    car_wash = False
                    print(car_wash)
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 충전소: ", end="")
        while(True):
            try:
                if (driver.find_element(By.ID, "lpg_yn").get_attribute('src') 
                   == "https://www.opinet.co.kr/images/user/gis/oil_station_service1_02_01_off.gif"):
                    gas = False
                    print(gas)
                else :
                    gas = True
                    print(gas)
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 경정비: ", end="")
        while(True):
            try:
                if (driver.find_element(By.ID, "maint_yn").get_attribute('src') 
                   == "https://www.opinet.co.kr/images/user/gis/oil_station_service1_03.gif"):
                    maintenance = True
                    print(maintenance)
                else :
                    maintenance = False
                    print(maintenance)
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 편의점: ", end="")
        while(True):
            try:
                if (driver.find_element(By.ID, "cvs_yn").get_attribute('src') 
                   == "https://www.opinet.co.kr/images/user/gis/oil_station_service1_04_off.gif"):
                    cvs = False
                    print(cvs)
                else :
                    cvs = True
                    print(cvs)
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        print("- 24시: ", end="")
        while(True):
            try:
                if (driver.find_element(By.ID, "sel24_yn").get_attribute('src') 
                   == "https://www.opinet.co.kr/images/user/gis/oil_station_service1_05.gif"):
                    sel24 = True
                    print(sel24)
                else :
                    sel24 = False
                    print(sel24)
                break
            except StaleElementReferenceException :
                continue
        #---------------------------------------------------------------------
        data.append((station_name, primium_price, regular_price, diesel_price, 
                     indoor_price, phone_number, address, brand, car_wash, gas, maintenance, cvs, sel24))
        print("-------------------------------------------------------")

len(data)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# [ 강남구 ]
#
# -------------------------------------
# 강남구 의 예상 주유소 수는  30 개 입니다.
# 강남구 의 실제 주유소 수는  30 개 입니다
# -------------------------------------
# [주유소 이름]  오일프러스 셀프 ( 1 / 30 )
# - 고급휘발유 가격: 1,899
# - 보통휘발유 가격: 1,719
# - 경유 가격: 1
)
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  (주)삼표에너지 고덕주유소 ( 9 / 13 )
# - 고급휘발유 가격: 1,999
# - 보통휘발유 가격: 1,796
# - 경유 가격: 1,658
# - 실내등유 가격: 1,699
# - 전화번호: 02-441-3327
# - 주소: 서울 강동구 고덕로 39 (암사동)
# - 상호명: GS칼텍스
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: True
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  (주)소모 성내주유소 ( 10 / 13 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,818
# - 경유 가격: 1,698
# - 실내등유 가격:
# - 전화번호: 02-479-3838
# - 주소: 서울 강동구 올림픽로 578 (성내동)
# - 상호명: GS칼텍스
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  주)지유에너지직영 오렌지주유소 ( 11 / 13 )
# - 고급휘발유 가격: 1,934
# - 보통휘발유 가격: 1,824
# - 경유 가격: 1,694
# - 실내등유 가격:
# - 전화번호: 02-484-6165
# - 주소: 서울 강동구 성안로 102 (성내동)
# - 상호명: SK에너지
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  천호현대주유소 ( 12 / 13 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,938
# - 경유 가격: 1,793
# - 실내등유 가격:
# - 전화번호: 02-484-9323
# - 주소: 서울 강동구 천중로 67 (천호동)
# - 상호명: HD현대오일뱅크
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  광성주유소 ( 13 / 13 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,968
# - 경유 가격: 1,858
# - 실내등유 가격:
# - 전화번호: 02-470-5133
# - 주소: 서울 강동구 올림픽로 673 (천호동)
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: True
# -------------------------------------------------------
#
# [ 강북구 ]
#
# -------------------------------------
# 강북구 의 예상 주유소 수는  10 개 입니다.
# 강북구 의 실제 주유소 수는  10 개 입니다
# -------------------------------------
# [주유소 이름]  (주)자연에너지 번동주유소 ( 1 / 10 )
# - 고급휘발유 가격: 1,849
# - 보통휘발유 가격: 1,645
# - 경유 가격: 1,515
# - 실내등유 가격:
# - 전화번호: 02-994-4458
# - 주소: 서울 강북구 한천로 963 (번동)
# - 상호명: HD현대오일뱅크
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  (주)석산에너지 ( 2 / 10 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,645
# - 경유 가격: 1,515
# - 실내등유 가격: 1,380
# - 전화번호: 02-980-1448
# - 주소: 서울 강북구 삼양로 316 (수유동)
# - 상호명: HD현대오일뱅크
# - 세차장: False
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  덕릉로주유소 ( 3 / 10 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,645
# - 경유 가격: 1,515
# - 실내등유 가격:
# - 전화번호: 02-989-9806
# - 주소: 서울 강북구 덕릉로 158 (번동)
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  (주)서울에너지 시민주유소 ( 4 / 10 )
# - 고급휘발유 가격: 1,849
# - 보통휘발유 가격: 1,645
# - 경유 가격: 1,515
# - 실내등유 가격:
# - 전화번호: 02-907-9496
# - 주소: 서울 강북구 인수봉로 185 (수유동)
# - 상호명: HD현대오일뱅크
# - 세차장: False
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  수유동주유소 ( 5 / 10 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,661
# - 경유 가격: 1,525
# - 실내등유 가격:
# - 전화번호: 02-902-9470
# - 주소: 서울 강북구 도봉로 395 (수유동)
# - 상호명: GS칼텍스
# - 세차장: False
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: True
# -------------------------------------------------------
# [주유소 이름]  씨앤에스유통㈜ 미아셀프주유소 ( 6 / 10 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,669
# - 경유 가격: 1,525
# - 실내등유 가격:
# - 전화번호: 02-945-7999
# - 주소: 서울 강북구 도봉로 200 (미아동)
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  ㈜지에스이앤알 미아주유소 ( 7 / 10 )
# - 고급휘발유 가격: 1,849
# - 보통휘발유 가격: 1,669
# - 경유 가격: 1,525
# - 실내등유 가격:
# - 전화번호: 02-987-5152
# - 주소: 서울 강북구 도봉로 122 (미아동)
# - 상호명: GS칼텍스
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  SK에너지(주) 매일주유소 ( 8 / 10 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,689
# - 경유 가격: 1,557
# - 실내등유 가격:
# - 전화번호: 02-982-8855
# - 주소: 서울 강북구 삼양로 217 (미아동)
# - 상호명: SK에너지
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: True
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  북서울고속주유소 ( 9 / 10 )
# - 고급휘발유 가격: 1,849
# - 보통휘발유 가격: 1,715
# - 경유 가격: 1,575
# - 실내등유 가격:
# - 전화번호: 02-907-5182
# - 주소: 서울 강북구 삼양로 410 (수유동)
# - 상호명: SK에너지
# - 세차장: False
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  대성석유(주)신광주유소 ( 10 / 10 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,729
# - 경유 가격: 1,579
# - 실내등유 가격: 1,500
# - 전화번호: 02-908-3320
# - 주소: 서울 강북구 삼양로 484
# - 상호명: GS칼텍스
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
#
# [ 강서구 ]
#
# -------------------------------------
# 강서구 의 예상 주유소 수는  33 개 입니다.
# 강서구 의 실제 주유소 수는  33 개 입니다
# -------------------------------------
# [주유소 이름]  화곡역주유소 ( 1 / 33 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,624
# - 경유 가격: 1,499
# - 실내등유 가격:
# - 전화번호: 02-2691-5151
# - 주소: 서울 강서구 강서로 154 (화곡동)
# - 상호명: 알뜰주유소
# - 세차장: False
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: True
# -------------------------------------------------------
# [주유소 이름]
)
# - 상호명: SK에너지
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  (주)자연에너지 대창주유소 ( 6 / 12 )
# - 고급휘발유 가격: 1,889
# - 보통휘발유 가격: 1,645
# - 경유 가격: 1,517
# - 실내등유 가격:
# - 전화번호: 02-434-1448
# - 주소: 서울 중랑구 동일로 636 (면목동)
# - 상호명: HD현대오일뱅크
# - 세차장: False
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  오천만주유소 ( 7 / 12 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,657
# - 경유 가격: 1,527
# - 실내등유 가격:
# - 전화번호: 070-7797-7474
# - 주소: 서울 중랑구 동일로 547 (면목동)
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  (주)태영 구도일주유소 한인 ( 8 / 12 )
# - 고급휘발유 가격: 1,877
# - 보통휘발유 가격: 1,687
# - 경유 가격: 1,567
# - 실내등유 가격:
# - 전화번호: 02-438-5151
# - 주소: 서울 중랑구 망우로 170
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  범아주유소 ( 9 / 12 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,729
# - 경유 가격: 1,569
# - 실내등유 가격: 1,600
# - 전화번호: 02-974-8356
# - 주소: 서울 중랑구 동일로 881
# - 상호명: S-OIL
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  신내주유소 ( 10 / 12 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,739
# - 경유 가격: 1,598
# - 실내등유 가격: 1,500
# - 전화번호: 02-2207-0523
# - 주소: 서울 중랑구 용마산로 705 (신내동)
# - 상호명: SK에너지
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  용마로주유소 ( 11 / 12 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,758
# - 경유 가격: 1,658
# - 실내등유 가격: 1,600
# - 전화번호: 02-439-3037
# - 주소: 서울 중랑구 용마산로 309 (면목동)
# - 상호명: SK에너지
# - 세차장: True
# - 충전소: False
# - 경정비: False
# - 편의점: False
# - 24시: False
# -------------------------------------------------------
# [주유소 이름]  신일셀프주유소 ( 12 / 12 )
# - 고급휘발유 가격:
# - 보통휘발유 가격: 1,798
# - 경유 가격: 1,698
# - 실내등유 가격: 1,590
# - 전화번호: 02-436-3651
# - 주소: 서울 중랑구 상봉로 58 (망우동)
# - 상호명: SK에너지
# - 세차장: True
# - 충전소: False
# - 경정비: True
# - 편의점: False
# - 24시: True
# -------------------------------------------------------
# 421

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 전처리

# %%
import pandas as pd
df = pd.DataFrame(data, columns=[
    '주유소명', '고급휘발유 가격', '보통휘발유 가격', '경유 가격', '실내 등유 가격', '전화번호', '주소', '상호명',
    '세차장', '충전소', '경정비', '편의점', '24시영업'
    ])

# %%
df
# Out:
#                     주유소명 고급휘발유 가격 보통휘발유 가격  경유 가격 실내 등유 가격          전화번호  \
# 0               오일프러스 셀프    1,899    1,719  1,638           02-3462-5100
# 1          지에스칼텍스㈜ 은마주유소    1,919    1,719  1,699           02-3452-1882
# 2    HD현대오일뱅크㈜직영 강남셀프주유소    1,899    1,719  1,638           02-3462-0018
# 3            (주)보성 세곡주유소    1,928    1,728  1,589            02-445-6870
# 4                  방죽주유소             1,737  1,609            02-459-3434
# ..                   ...      ...      ...    ...      ...           ...
# 416      (주)태영 구도일주유소 한인    1,877    1,687  1,567            02-438-5151
# 417                범아주유소             1,729  1,569    1,600   02-974-8356
# 418                신내주유소             1,739  1,598    1,500  02-2207-0523
# 419               용마로주유소             1,758  1,658    1,600   02-439-3037
# 420              신일셀프주유소             1,798  1,698    1,590   02-436-3651
#
#                           주소       상호명   세차장    충전소    경정비    편의점  24시영업
# 0    서울 강남구 남부순환로 2651 (도곡동)     SK에너지  True  False   True  False   True
# 1            서울 강남구 영동대로 235     GS칼텍스  True  False   True  False  False
# 2             서울 강남구 도곡로 208  HD현대오일뱅크  True  False  False  False  False
# 3       서울 강남구 헌릉로 731 (세곡동)     SK에너지  True  False  False  False  False
# 4      서울 강남구 밤고개로 215 (율현동)     GS칼텍스  True  False  False  False  False
# ..                       ...       ...   ...    ...    ...    ...    ...
# 416           서울 중랑구 망우로 170     S-OIL  True  False   True  False  False
# 417           서울 중랑구 동일로 881     S-OIL  True  False   True  False  False
# 418    서울 중랑구 용마산로 705 (신내동)     SK에너지  True  False  False  False  False
# 419    서울 중랑구 용마산로 309 (면목동)     SK에너지  True  False  False  False  False
# 420      서울 중랑구 상봉로 58 (망우동)     SK에너지  True  False   True  False   True
#
# [421 rows x 13 columns]

# %%
df.to_csv('/home/jinhyuk3me/dev_ws/eda/data/opinet_data/opinet.csv')

# %% [markdown]
# ---

# %% [markdown]
# 가격 column의 value들은 전부 숫자여야 함

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   주유소명      421 non-null    object
#  1   고급휘발유 가격  421 non-null    object
#  2   보통휘발유 가격  421 non-null    object
#  3   경유 가격     421 non-null    object
#  4   실내 등유 가격  421 non-null    object
#  5   전화번호      421 non-null    object
#  6   주소        421 non-null    object
#  7   상호명       421 non-null    object
#  8   세차장       421 non-null    bool
#  9   충전소       421 non-null    bool
#  10  경정비       421 non-null    bool
#  11  편의점       421 non-null    bool
#  12  24시영업     421 non-null    bool
# dtypes: bool(5), object(8)
# memory usage: 28.5+ KB

# %% [markdown]
# 가격들이 전부 string이군요

# %%
import numpy as np

df['고급휘발유 가격'] = pd.to_numeric(df['고급휘발유 가격'].str.replace(",",''))
df['보통휘발유 가격'] = pd.to_numeric(df['보통휘발유 가격'].str.replace(",",''))
df['경유 가격'] = pd.to_numeric(df['경유 가격'].str.replace(",",''))
df['실내 등유 가격'] = pd.to_numeric(df['실내 등유 가격'].str.replace(",",''))

# %%
df.head()
# Out:
#                   주유소명  고급휘발유 가격  보통휘발유 가격  경유 가격  실내 등유 가격          전화번호  \
# 0             오일프러스 셀프    1899.0      1719   1638       NaN  02-3462-5100
# 1        지에스칼텍스㈜ 은마주유소    1919.0      1719   1699       NaN  02-3452-1882
# 2  HD현대오일뱅크㈜직영 강남셀프주유소    1899.0      1719   1638       NaN  02-3462-0018
# 3          (주)보성 세곡주유소    1928.0      1728   1589       NaN   02-445-6870
# 4                방죽주유소       NaN      1737   1609       NaN   02-459-3434
#
#                         주소       상호명   세차장    충전소    경정비    편의점  24시영업
# 0  서울 강남구 남부순환로 2651 (도곡동)     SK에너지  True  False   True  False   True
# 1          서울 강남구 영동대로 235     GS칼텍스  True  False   True  False  False
# 2           서울 강남구 도곡로 208  HD현대오일뱅크  True  False  False  False  False
# 3     서울 강남구 헌릉로 731 (세곡동)     SK에너지  True  False  False  False  False
# 4    서울 강남구 밤고개로 215 (율현동)     GS칼텍스  True  False  False  False  False

# %% [markdown]
# 잘 바뀌었으니 저장하겠습니다

# %%
df.to_csv('/home/jinhyuk3me/dev_ws/eda/data/opinet_data/opinet2.csv')

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석 및 시각화

# %%
import pandas as pd

df = pd.read_csv("/home/jinhyuk3me/dev_ws/eda/data/opinet_data/opinet2.csv", index_col=0)

# %% [markdown]
# ### 지역별 분석

# %%
df['구'] = [addr.split(' ')[1] for addr in df['주소']]
df.head()
# Out:
#                   주유소명  고급휘발유 가격  보통휘발유 가격  경유 가격  실내 등유 가격          전화번호  \
# 0             오일프러스 셀프    1899.0      1719   1638       NaN  02-3462-5100
# 1        지에스칼텍스㈜ 은마주유소    1919.0      1719   1699       NaN  02-3452-1882
# 2  HD현대오일뱅크㈜직영 강남셀프주유소    1899.0      1719   1638       NaN  02-3462-0018
# 3          (주)보성 세곡주유소    1928.0      1728   1589       NaN   02-445-6870
# 4                방죽주유소       NaN      1737   1609       NaN   02-459-3434
#
#                         주소       상호명   세차장    충전소    경정비    편의점  24시영업    구
# 0  서울 강남구 남부순환로 2651 (도곡동)     SK에너지  True  False   True  False   True  강남구
# 1          서울 강남구 영동대로 235     GS칼텍스  True  False   True  False  False  강남구
# 2           서울 강남구 도곡로 208  HD현대오일뱅크  True  False  False  False  False  강남구
# 3     서울 강남구 헌릉로 731 (세곡동)     SK에너지  True  False  False  False  False  강남구
# 4    서울 강남구 밤고개로 215 (율현동)     GS칼텍스  True  False  False  False  False  강남구

# %% [markdown]
# 지역별 비교는 평균치로 해야 할 것 같습니다

# %%
import numpy as np

pivot_table1 = df.pivot_table(index='구', values=[
    '고급휘발유 가격', '보통휘발유 가격', '경유 가격', '실내 등유 가격'
    ], aggfunc=np.mean)
pivot_table2 = df.pivot_table(index='구', values=[
    '세차장', '충전소', '경정비', '편의점', '24시영업',
    ], aggfunc=np.mean)
# Out:
# /tmp/ipykernel_8072/2999622559.py:3: FutureWarning: The provided callable <function mean at 0x795fab7c35b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table1 = df.pivot_table(index='구', values=[
# /tmp/ipykernel_8072/2999622559.py:6: FutureWarning: The provided callable <function mean at 0x795fab7c35b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table2 = df.pivot_table(index='구', values=[

# %% [markdown]
# ---

# %% [markdown]
# 구별 가격 평균 정보는 pivot_table1에

# %%
pivot_table1.head()
# Out:
#            경유 가격     고급휘발유 가격     보통휘발유 가격     실내 등유 가격
# 구
# 강남구  1830.733333  2176.000000  1945.833333  1741.500000
# 강동구  1662.769231  1959.625000  1788.230769  1599.750000
# 강북구  1534.600000  1849.000000  1671.200000  1440.000000
# 강서구  1574.454545  1906.125000  1704.818182  1534.142857
# 관악구  1621.928571  1967.833333  1749.357143  1411.400000

# %% [markdown]
# 구별 부가 서비스 평균 정보는 pivot_table2에

# %% [markdown]
# True=1, False=0으로 놓으면 해당 서비스를 제공하는 station의 비율을 알 수 있을 것이다

# %%
pivot_table2.head()
# Out:
#         24시영업       경정비       세차장       충전소       편의점
# 구
# 강남구  0.366667  0.300000  0.900000  0.000000  0.000000
# 강동구  0.076923  0.384615  0.923077  0.000000  0.076923
# 강북구  0.100000  0.100000  0.600000  0.000000  0.100000
# 강서구  0.272727  0.303030  0.787879  0.060606  0.242424
# 관악구  0.142857  0.214286  0.714286  0.000000  0.071429

# %% [markdown]
# ---

# %% [markdown]
# 가격 정보 분석

# %% [markdown]
# 지역별 보통휘발유 가격 분석

# %%
import folium
import json

geo_path = "/home/jinhyuk3me/dev_ws/eda/data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='OpenStreetMap')
setting = folium.Choropleth(
    geo_data=geo_str,
    data=pivot_table1,
    columns=[pivot_table1.index, '보통휘발유 가격'],
    key_on="feature.properties.name",
    fill_color="PuRd"
)
setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e00434cbb690f0fb4dffbc871f88351d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e00434cbb690f0fb4dffbc871f88351d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e00434cbb690f0fb4dffbc871f88351d = L.map(
#                 &quot;map_e00434cbb690f0fb4dffbc871f88351d&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb92329cb87b8207ae95171382584a71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb92329cb87b8207ae95171382584a71.addTo(map_e00434cbb690f0fb4dffbc871f88351d);
#
#
#             var choropleth_34a16ae07d1dafb29393799db95361a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_0415218109d5edb257a492787123799f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0415218109d5edb257a492787123799f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0415218109d5edb257a492787123799f = L.geoJson(null, {
#                 onEachFeature: geo_json_0415218109d5edb257a492787123799f_onEachFeature,
#
#                 style: geo_json_0415218109d5edb257a492787123799f_styler,
#             ...{
# }
#         });
#
#         function geo_json_0415218109d5edb257a492787123799f_add (data) {
#             geo_json_0415218109d5edb257a492787123799f
#                 .addData(data);
#         }
#             geo_json_0415218109d5edb257a492787123799f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.07

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.figure(figsize=(14,12))
plt.barh(pivot_table2.index, pivot_table1['보통휘발유 가격'], color='blue')
plt.title('지역별 보통휘발유 가격')
plt.xlabel('가격')
plt.ylabel('지역')
plt.xlim(1500, 2500)
plt.grid()
plt.show()

# %% [markdown]
# 지역별 고급휘발유 가격

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='OpenStreetMap')
setting = folium.Choropleth(
    geo_data=geo_str,
    data=pivot_table1,
    columns=[pivot_table1.index, '고급휘발유 가격'],
    key_on="feature.properties.name",
    fill_color="PuRd"
)
setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce63441927dc8294e9486ed336b19562 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce63441927dc8294e9486ed336b19562&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce63441927dc8294e9486ed336b19562 = L.map(
#                 &quot;map_ce63441927dc8294e9486ed336b19562&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb104eee21a1df910c279d7789687823 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb104eee21a1df910c279d7789687823.addTo(map_ce63441927dc8294e9486ed336b19562);
#
#
#             var choropleth_c4b7057c08ac42b4276c00cecfc515a9 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_89b184282b50821c28f6af6787cda18d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3c4\ubd09\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_89b184282b50821c28f6af6787cda18d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_89b184282b50821c28f6af6787cda18d = L.geoJson(null, {
#                 onEachFeature: geo_json_89b184282b50821c28f6af6787cda18d_onEachFeature,
#
#                 style: geo_json_89b184282b50821c28f6af6787cda18d_styler,
#             ...{
# }
#         });
#
#         function geo_json_89b184282b50821c28f6af6787cda18d_add (data) {
#             geo_json_89b184282b50821c28f6af6787cda18d
#                 .addData(data);
#         }
#             geo_json_89b184282b50821c28f6af6787cda18d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.146

# %%
plt.figure(figsize=(14,12))
plt.barh(pivot_table2.index, pivot_table1['고급휘발유 가격'], color='blue')
plt.title('지역별 고급휘발유 가격')
plt.xlabel('가격')
plt.ylabel('지역')
plt.xlim(1500, 2500)
plt.grid()
plt.show()

# %% [markdown]
# 지역별 경유 가격

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='OpenStreetMap')
setting = folium.Choropleth(
    geo_data=geo_str,
    data=pivot_table1,
    columns=[pivot_table1.index, '경유 가격'],
    key_on="feature.properties.name",
    fill_color="PuRd"
)
setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b05ff68213f5b850dfa74864e710f45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b05ff68213f5b850dfa74864e710f45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b05ff68213f5b850dfa74864e710f45 = L.map(
#                 &quot;map_0b05ff68213f5b850dfa74864e710f45&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cac68f4b6be7fe9691405b53397e925 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2cac68f4b6be7fe9691405b53397e925.addTo(map_0b05ff68213f5b850dfa74864e710f45);
#
#
#             var choropleth_6948319a9493316aa9845ba5b24ce0fc = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_cbfdd4c99d66b602a806e5646e082896_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_cbfdd4c99d66b602a806e5646e082896_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cbfdd4c99d66b602a806e5646e082896 = L.geoJson(null, {
#                 onEachFeature: geo_json_cbfdd4c99d66b602a806e5646e082896_onEachFeature,
#
#                 style: geo_json_cbfdd4c99d66b602a806e5646e082896_styler,
#             ...{
# }
#         });
#
#         function geo_json_cbfdd4c99d66b602a806e5646e082896_add (data) {
#             geo_json_cbfdd4c99d66b602a806e5646e082896
#                 .addData(data);
#         }
#             geo_json_cbfdd4c99d66b602a806e5646e082896_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.07191460

# %%
plt.figure(figsize=(14,12))
plt.barh(pivot_table2.index, pivot_table1['경유 가격'], color='blue')
plt.title('지역별 경유 가격')
plt.xlabel('가격')
plt.ylabel('지역')
plt.xlim(1500, 2500)
plt.grid()
plt.show()

# %% [markdown]
# 지역별 등유 가격

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='OpenStreetMap')
setting = folium.Choropleth(
    geo_data=geo_str,
    data=pivot_table1,
    columns=[pivot_table1.index, '실내 등유 가격'],
    key_on="feature.properties.name",
    fill_color="PuRd"
)
setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c71d21454160f37041baec9dd53dbaf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c71d21454160f37041baec9dd53dbaf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c71d21454160f37041baec9dd53dbaf = L.map(
#                 &quot;map_9c71d21454160f37041baec9dd53dbaf&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef8b94acd6d24a5e66ebed841d66a1e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef8b94acd6d24a5e66ebed841d66a1e5.addTo(map_9c71d21454160f37041baec9dd53dbaf);
#
#
#             var choropleth_2fd9a90cccead26126237eafe9754ef0 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_bd42fda703957389a8f549b10c5ebac1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_bd42fda703957389a8f549b10c5ebac1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bd42fda703957389a8f549b10c5ebac1 = L.geoJson(null, {
#                 onEachFeature: geo_json_bd42fda703957389a8f549b10c5ebac1_onEachFeature,
#
#                 style: geo_json_bd42fda703957389a8f549b10c5ebac1_styler,
#             ...{
# }
#         });
#
#         function geo_json_bd42fda703957389a8f549b10c5ebac1_add (data) {
#             geo_json_bd42fda703957389a8f549b10c5ebac1
#                 .addData(data);
#         }
#             geo_json_bd42fda703957389a8f549b10c5ebac1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.5022401358766

# %%
plt.figure(figsize=(14,12))
plt.barh(pivot_table2.index, pivot_table1['실내 등유 가격'], color='blue')
plt.title('지역별 등유 가격')
plt.xlabel('가격')
plt.ylabel('지역')
plt.xlim(1400, 1800)
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 부가서비스 정보 분석

# %% [markdown]
# 24시간 영업 정보

# %%
import folium
import json

geo_path = "/home/jinhyuk3me/dev_ws/eda/data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='OpenStreetMap')
setting = folium.Choropleth(
    geo_data=geo_str,
    data=pivot_table2,
    columns=[pivot_table2.index, '24시영업'],
    key_on="feature.properties.name",
    fill_color="PuRd"
)
setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9db269924053850d0802a088c896230 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9db269924053850d0802a088c896230&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9db269924053850d0802a088c896230 = L.map(
#                 &quot;map_a9db269924053850d0802a088c896230&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fccdc6585dd70bf6978a1c168890dd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fccdc6585dd70bf6978a1c168890dd7.addTo(map_a9db269924053850d0802a088c896230);
#
#
#             var choropleth_d0b443af20df1a0cd59cf7e81e461ea0 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_d321c71bc0940a0ea75c7ea84f2a378c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d321c71bc0940a0ea75c7ea84f2a378c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d321c71bc0940a0ea75c7ea84f2a378c = L.geoJson(null, {
#                 onEachFeature: geo_json_d321c71bc0940a0ea75c7ea84f2a378c_onEachFeature,
#
#                 style: geo_json_d321c71bc0940a0ea75c7ea84f2a378c_styler,
#             ...{
# }
#         });
#
#         function geo_json_d321c71bc0940a0ea75c7ea84f2a378c_add (data) {
#             geo_json_d321c71bc0940a0ea75c7ea84f2a378c
#                 .addData(data);
#         }
#             geo_json_d321c71bc0940a0ea75c7ea84f2a378c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.146

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.figure(figsize=(14,12))
plt.barh(pivot_table2.index, pivot_table2['24시영업'], color='blue')
plt.title('구별 주유소 24시간 영업 비율')
plt.xlim(0,0.6)
plt.xlabel('비율')
plt.ylabel('지역')
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 편의점 영업 정보

# %%
setting = folium.Choropleth(
    geo_data=geo_str,
    data=pivot_table2,
    columns=[pivot_table2.index, '편의점'],
    key_on="feature.properties.name",
    fill_color="PuRd"
)
setting.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9db269924053850d0802a088c896230 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9db269924053850d0802a088c896230&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9db269924053850d0802a088c896230 = L.map(
#                 &quot;map_a9db269924053850d0802a088c896230&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fccdc6585dd70bf6978a1c168890dd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fccdc6585dd70bf6978a1c168890dd7.addTo(map_a9db269924053850d0802a088c896230);
#
#
#             var choropleth_d0b443af20df1a0cd59cf7e81e461ea0 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_d321c71bc0940a0ea75c7ea84f2a378c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d321c71bc0940a0ea75c7ea84f2a378c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d321c71bc0940a0ea75c7ea84f2a378c = L.geoJson(null, {
#                 onEachFeature: geo_json_d321c71bc0940a0ea75c7ea84f2a378c_onEachFeature,
#
#                 style: geo_json_d321c71bc0940a0ea75c7ea84f2a378c_styler,
#             ...{
# }
#         });
#
#         function geo_json_d321c71bc0940a0ea75c7ea84f2a378c_add (data) {
#             geo_json_d321c71bc0940a0ea75c7ea84f2a378c
#                 .addData(data);
#         }
#             geo_json_d321c71bc0940a0ea75c7ea84f2a378c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.146

# %%
plt.figure(figsize=(14,12))
plt.barh(pivot_table2.index, pivot_table2['편의점'], color='blue')
plt.title('구별 주유소 편의점 영업 비율')
plt.xlim(0,0.4)
plt.xlabel('비율')
plt.ylabel('지역')
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 각 지점별 분석

# %% [markdown]
# 서울에서 가장 비싼/싼 주유소 상위 20개

# %%
import googlemaps

gmaps_key = "*************************"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat_list = []
lng_list = []   

for idx, row in tqdm(df.iterrows(), total=len(df.index)):
    geocode = gmaps.geocode(row["주소"])
    lat = geocode[0].get("geometry")["location"]["lat"] if len(geocode) > 0 else np.nan
    lng = geocode[0].get("geometry")["location"]["lng"] if len(geocode) > 0 else np.nan
    lat_list.append(lat)
    lng_list.append(lng)
    
df['위도'] = lat_list
df['경도'] = lng_list

df.head()
# Out:
#   0%|          | 0/422 [00:00<?, ?it/s]
#                   주유소명  고급휘발유 가격  보통휘발유 가격  경유 가격  실내 등유 가격          전화번호  \
# 0  HD현대오일뱅크㈜직영 강남셀프주유소    1899.0      1719   1638       NaN  02-3462-0018
# 1  HD현대오일뱅크㈜직영 강남셀프주유소    1899.0      1719   1699       NaN  02-3452-1882
# 2          (주)보성 세곡주유소    1928.0      1728   1589       NaN   02-445-6870
# 3          (주)보성 세곡주유소    1928.0      1737   1609       NaN   02-459-3434
# 4             오일프러스 셀프    1899.0      1739   1638       NaN  02-3462-5100
#
#                         주소       상호명   세차장    충전소    경정비    편의점  24시영업    구  \
# 0           서울 강남구 도곡로 208  HD현대오일뱅크  True  False  False  False  False  강남구
# 1          서울 강남구 영동대로 235     GS칼텍스  True  False   True  False  False  강남구
# 2     서울 강남구 헌릉로 731 (세곡동)     SK에너지  True  False  False  False  False  강남구
# 3    서울 강남구 밤고개로 215 (율현동)     GS칼텍스  True  False  False  False  False  강남구
# 4  서울 강남구 남부순환로 2651 (도곡동)     SK에너지  True  False   True  False   True  강남구
#
#           위도          경도
# 0  37.492295  127.041860
# 1  37.500072  127.067285
# 2  37.467157  127.118708
# 3  37.474993  127.106887
# 4  37.485839  127.039672

# %% [markdown]
# ---

# %% [markdown]
# 백업

# %%
df.to_csv('/home/jinhyuk3me/dev_ws/eda/data/opinet_data/opinet3.csv')

# %%
df = pd.read_csv("/home/jinhyuk3me/dev_ws/eda/data/opinet_data/opinet3.csv", index_col=0)

# %% [markdown]
# ---

# %% [markdown]
# duplicated 검사를 해보니 실제 중복된건 아니고 그냥 너무 붙어있어서 반올림했을 때 우연히 같게 계산되는듯

# %%
df[df.duplicated(subset=['위도', '경도'])]
# Out:
#                   주유소명  고급휘발유 가격  보통휘발유 가격  경유 가격  실내 등유 가격          전화번호  \
# 80   HD현대오일뱅크㈜직영 가양주유소    1955.0      1759   1619       NaN  02-3661-9470
# 108          서울중앙고속주유소    1799.0      1675   1545       NaN   02-463-2231
# 109     정해네트웍스(주)일진주유소    1824.0      1675   1545       NaN   02-461-5152
#
#                        주소       상호명    세차장    충전소    경정비    편의점  24시영업    구  \
# 80   서울 강서구 양천로 391 (가양동)  HD현대오일뱅크   True  False  False  False  False  강서구
# 108  서울 광진구 동일로 345 (중곡동)     SK에너지  False  False  False  False  False  광진구
# 109  서울 광진구 동일로 413 (중곡동)     S-OIL   True  False  False  False   True  광진구
#
#             위도          경도
# 80   37.567880  126.851079
# 108  37.563544  127.088830
# 109  37.563544  127.088830

# %%
df[df['위도']==37.563544]
# Out:
# Empty DataFrame
# Columns: [주유소명, 고급휘발유 가격, 보통휘발유 가격, 경유 가격, 실내 등유 가격, 전화번호, 주소, 상호명, 세차장, 충전소, 경정비, 편의점, 24시영업, 구, 위도, 경도]
# Index: []

# %%
df[df['위도'].round(6)==37.563544]
# Out:
#                주유소명  고급휘발유 가격  보통휘발유 가격  경유 가격  실내 등유 가격         전화번호  \
# 102  (주)자연에너지 중원주유소       NaN      1645   1517       NaN  02-498-8683
# 108       서울중앙고속주유소    1799.0      1675   1545       NaN  02-463-2231
# 109  정해네트웍스(주)일진주유소    1824.0      1675   1545       NaN  02-461-5152
#
#                        주소       상호명    세차장    충전소    경정비    편의점  24시영업    구  \
# 102  서울 광진구 동일로 398 (중곡동)  HD현대오일뱅크   True  False  False  False  False  광진구
# 108  서울 광진구 동일로 345 (중곡동)     SK에너지  False  False  False  False  False  광진구
# 109  서울 광진구 동일로 413 (중곡동)     S-OIL   True  False  False  False   True  광진구
#
#             위도         경도
# 102  37.563544  127.08883
# 108  37.563544  127.08883
# 109  37.563544  127.08883

# %% [markdown]
# ---

# %%
df_desc = df[['주유소명','보통휘발유 가격','위도','경도']].sort_values(by='보통휘발유 가격', ascending=False)[:20]
df_asc = df[['주유소명','보통휘발유 가격','위도','경도']].sort_values(by='보통휘발유 가격', ascending=True)[:20]

# %%
df_desc
# Out:
#                      주유소명  보통휘발유 가격         위도          경도
# 377                 서계주유소      2971  37.552329  126.968946
# 409                 서남주유소      2756  37.558375  126.972094
# 29         (주)만정에너지 삼보주유소      2620  37.511521  127.047172
# 28    (주)제이제이네트웍스 제이제이주유소      2548  37.517647  127.035735
# 408                 필동주유소      2539  37.560912  126.993713
# 27                SK논현주유소      2435  37.518637  127.028238
# 26           (주)소모 쎈트럴주유소      2388  37.501421  127.059141
# 400        (주)대양씨앤씨 사직주유소      2375  37.574505  126.966607
# 376                 한석주유소      2310  37.521390  126.965557
# 264         (주)옥수하이웨이스테이션      2298  37.541024  127.011368
# 375                  에너비스      2297  37.536041  127.006128
# 374                  한남지점      2297  37.534733  127.006095
# 373  HD현대오일뱅크(주)직영 소월길주유소      2291  37.550584  126.976996
# 130                 구로주유소      2290  37.490960  126.883648
# 25          ㈜새서울석유 새서울주유소      2288  37.525835  127.026542
# 372                동자동주유소      2281  37.552794  126.974797
# 371    HD현대오일뱅크㈜직영 갈월동주유소      2281  37.547038  126.972236
# 24                  명품주유소      2278  37.494270  127.045509
# 23                  대청주유소      2266  37.492474  127.085679
# 248        (주)선문에너지 중앙주유소      2258  37.481551  127.042234

# %%
df_asc
# Out:
#                   주유소명  보통휘발유 가격         위도          경도
# 249        (주)서울에너지 직영      1605  37.564261  127.055685
# 250             ㈜성동에너지      1605  37.561430  127.062327
# 169     (주)자연에너지 국민주유소      1635  37.572965  127.065037
# 54     이케이에너지(주) 강서주유소      1638  37.549163  126.846996
# 316              현대주유소      1638  37.533873  126.829262
# 53              화곡역주유소      1638  37.540719  126.841530
# 410              우림주유소      1643  37.592332  127.099105
# 265             ㈜원천주유소      1643  37.614895  127.052732
# 317              신월주유소      1644  37.520061  126.844080
# 267              신방주유소      1645  37.585556  127.031846
# 266     ㈜스마일에너지 신동방주유소      1645  37.613429  127.038104
# 44      (주)서울에너지 시민주유소      1645  37.636202  127.012822
# 46              덕릉로주유소      1645  37.634976  127.031318
# 172     (주)정건에너지 배봉로지점      1645  37.580015  127.051050
# 43            (주)석산에너지      1645  37.631633  127.017939
# 45      (주)자연에너지 번동주유소      1645  37.635587  127.033049
# 171              재정주유소      1645  37.575704  127.057439
# 100            (주)창원CW      1645  37.545104  127.080497
# 102     (주)자연에너지 중원주유소      1645  37.563544  127.088830
# 269  이케이에너지(주) 강산제2주유소      1645  37.609185  127.010031

# %% [markdown]
# 서울에서 보통휘발유 값이 제일 비싼 주유소 상위 20개

# %%
mapping = folium.Map(location=[df_desc['위도'].iloc[0], df_desc['경도'].iloc[0]], zoom_start=12)
for idx, row in df_desc.iterrows():
    if row['위도'] == np.nan or row['경도'] == np.nan:
        continue
    else:
        folium.Marker([row['위도'], row['경도']], popup=row['주유소명']).add_to(mapping) 
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ce568fad3a5c62c067b387ab3804b5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ce568fad3a5c62c067b387ab3804b5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ce568fad3a5c62c067b387ab3804b5e = L.map(
#                 &quot;map_4ce568fad3a5c62c067b387ab3804b5e&quot;,
#                 {
#                     center: [37.5523286, 126.9689462],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_852c66068dd2492521b9bc36d7f520c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_852c66068dd2492521b9bc36d7f520c0.addTo(map_4ce568fad3a5c62c067b387ab3804b5e);
#
#
#             var marker_a2a487783d2d3d2f2ff7a45dcd4e29d4 = L.marker(
#                 [37.5523286, 126.9689462],
#                 {
# }
#             ).addTo(map_4ce568fad3a5c62c067b387ab3804b5e);
#
#
#         var popup_905226344c5a3abf1c129158fc65a74f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dfc3dc1027b24d762694897d8a43606 = $(`&lt;div id=&quot;html_2dfc3dc1027b24d762694897d8a43606&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서계주유소&lt;/div&gt;`)[0];
#                 popup_905226344c5a3abf1c129158fc65a74f.setContent(html_2dfc3dc1027b24d762694897d8a43606);
#
#
#
#         marker_a2a487783d2d3d2f2ff7a45dcd4e29d4.bindPopup(popup_905226344c5a3abf1c129158fc65a74f)
#         ;
#
#
#
#
#             var marker_750c820daa58e28beaf1ea4f65e92798 = L.marker(
#                 [37.5583749, 126.9720939],
#                 {
# }
#             ).addTo(map_4ce568fad3a5c62c067b387ab3804b5e);
#
#
#         var popup_2e288bd547e7281e21f5e5fc99bbfd10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19e0b2bb11c482da667c8101a4395a70 = $(`&lt;div id=&quot;html_19e0b2bb11c482da667c8101a4395a70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서남주유소&lt;/div&gt;`)[0];
#                 popup_2e288bd547e7281e21f5e5fc99bbfd10.setContent(html_19e0b2bb11c482da667c8101a4395a70);
#
#
#
#         marker_750c820daa58e28beaf1ea4f65e92798.bindPopup(popup_2e288bd547e7281e21f5e5fc99bbfd10)
#         ;
#
#
#
#
#             var marker_4669ddd611295362914e2bce8ce9ddb9 = L.marker(
#                 [37.5115207, 127.0471716],
#                 {
# }
#             ).addTo(map_4ce568fad3a5c62c067b387ab3804b5e);
#
#
#         var popup_0faa60a3b9e05d9d737d98d0ac19171f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64452f6bcc5d9615a591ebda3672b325 = $(`&lt;div id=&quot;html_64452f6bcc5d9615a591ebda3672b325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)만정에너지 삼보주유소&lt;/div&gt;`)[0];
#                 popup_0faa60a3b9e05d9d737d98d0ac19171f.setContent(html_64452f6bcc5d9615a591ebda3672b325);
#
#
#
#         marker_4669ddd611295362914e2bce8ce9ddb9.bindPopup(popup_0faa60a3b9e05d9d737d98d0ac19171f)
#         ;
#
#
#
#
#             var marker_c8fae9c634105bb1ecdec1b09860c48a = L.marker(
#                 [37.5176472, 127.0357349],
#                 {
# }
#             ).addTo(map_4ce568fad3a5c62c067b387ab3804b5e);
#
#
#         var popup_37537860f6f476f3c6ae92ecdd17e37f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ded809a0adfb55d4e2db0d7b07f719d = $(`&lt;div id=&quot;html_8ded809a0adfb55d4e2db0d7b07f719d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)제이제이네트웍스 제이제이주유소&lt;/div&gt;`)[0];
#                 popup_37537860f6f476f3c6ae92ecdd17e37f.setContent(html_8ded809a0adfb55d4e2db0d7b07f719d);
#
#
#
#         marker_c8fae9c634105bb1ecdec1b09860c48a.bindPopup(popup_37537860f6f476f3c6ae92ecdd17e37f)
#         ;
#
#
#
#
#             var marker_1dc95a59e4b97a8eefa0aa69af528aad = L.marker(
#                 [37.56091199999999, 126.9937135],
#                 {
# }
#             ).addTo(map_4ce568fad3a5c62c067b387ab3804b5e);
#
#
#         var popup_49585c9e39266923af8d53dfd2fed126 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2e57e9c8e6e99b91cde32f85f88c6f5 = $(`&lt;div id=&quot;html_f2e57e9c8e6e99b91cde32f85f88c6f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;필동주유소&lt;/div&gt;`)[0];
#                 popup_49585c9e39266923af8d53dfd2fed126.setContent(html_f2e57e9c8e6e99b91cde32f85f88c6f5);
#
#
#
#         marker_1dc95a59e4b97a8eefa0aa69af528aad.bindPopup(popup_49585c9e39266923af8d53dfd2fed126)
#         ;
#
#
#
#
#             var marker_6832573d095a99fede006552357e5d5d = L.marker(
#                 [37.5186368, 127.028238],

# %% [markdown]
# 서울에서 보통 휘발유 값이 제일 싼 상위 20개

# %%
mapping = folium.Map(location=[df_asc['위도'].iloc[0], df_asc['경도'].iloc[0]], zoom_start=12)
for idx, row in df_asc.iterrows():
    if row['위도'] == np.nan or row['경도'] == np.nan:
        continue
    else:
        folium.Marker([row['위도'], row['경도']], popup=row['주유소명']).add_to(mapping) 
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2724366050a47a7261bcc106a4b84fbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2724366050a47a7261bcc106a4b84fbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2724366050a47a7261bcc106a4b84fbc = L.map(
#                 &quot;map_2724366050a47a7261bcc106a4b84fbc&quot;,
#                 {
#                     center: [37.56426070000001, 127.055685],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dfcffcec459614f5f6e14f209141208 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7dfcffcec459614f5f6e14f209141208.addTo(map_2724366050a47a7261bcc106a4b84fbc);
#
#
#             var marker_2d52ad05b993426b38afdc441a25cbc6 = L.marker(
#                 [37.56426070000001, 127.055685],
#                 {
# }
#             ).addTo(map_2724366050a47a7261bcc106a4b84fbc);
#
#
#         var popup_79e3432f2ba8ddc94f1856571e52dd03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00a9bb4a549a952b31fd896e8e5f0769 = $(`&lt;div id=&quot;html_00a9bb4a549a952b31fd896e8e5f0769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)서울에너지 직영&lt;/div&gt;`)[0];
#                 popup_79e3432f2ba8ddc94f1856571e52dd03.setContent(html_00a9bb4a549a952b31fd896e8e5f0769);
#
#
#
#         marker_2d52ad05b993426b38afdc441a25cbc6.bindPopup(popup_79e3432f2ba8ddc94f1856571e52dd03)
#         ;
#
#
#
#
#             var marker_062ca78e0ad633c5e03af2b1c1e6e549 = L.marker(
#                 [37.5614303, 127.0623272],
#                 {
# }
#             ).addTo(map_2724366050a47a7261bcc106a4b84fbc);
#
#
#         var popup_104378cfae12a73b2810b359b36bd989 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06b43688d696b6a71e5223be8cfbd874 = $(`&lt;div id=&quot;html_06b43688d696b6a71e5223be8cfbd874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;㈜성동에너지&lt;/div&gt;`)[0];
#                 popup_104378cfae12a73b2810b359b36bd989.setContent(html_06b43688d696b6a71e5223be8cfbd874);
#
#
#
#         marker_062ca78e0ad633c5e03af2b1c1e6e549.bindPopup(popup_104378cfae12a73b2810b359b36bd989)
#         ;
#
#
#
#
#             var marker_42171a585ab20d4bb994d113f308d952 = L.marker(
#                 [37.572965, 127.065037],
#                 {
# }
#             ).addTo(map_2724366050a47a7261bcc106a4b84fbc);
#
#
#         var popup_5ab5d49dbf86feef41190cf1631063f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d489f9807a0c8efcb9b45cc2f48f7c3 = $(`&lt;div id=&quot;html_4d489f9807a0c8efcb9b45cc2f48f7c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)자연에너지 국민주유소&lt;/div&gt;`)[0];
#                 popup_5ab5d49dbf86feef41190cf1631063f0.setContent(html_4d489f9807a0c8efcb9b45cc2f48f7c3);
#
#
#
#         marker_42171a585ab20d4bb994d113f308d952.bindPopup(popup_5ab5d49dbf86feef41190cf1631063f0)
#         ;
#
#
#
#
#             var marker_07349c9501cf92082f8fc3c3e90694ff = L.marker(
#                 [37.549163, 126.8469964],
#                 {
# }
#             ).addTo(map_2724366050a47a7261bcc106a4b84fbc);
#
#
#         var popup_c3e38a2c79ec75e23c41370639217009 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0000a28f34988a1f74bcff6859a7a39 = $(`&lt;div id=&quot;html_c0000a28f34988a1f74bcff6859a7a39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이케이에너지(주) 강서주유소&lt;/div&gt;`)[0];
#                 popup_c3e38a2c79ec75e23c41370639217009.setContent(html_c0000a28f34988a1f74bcff6859a7a39);
#
#
#
#         marker_07349c9501cf92082f8fc3c3e90694ff.bindPopup(popup_c3e38a2c79ec75e23c41370639217009)
#         ;
#
#
#
#
#             var marker_0a6e0b2270bb9bd047ccdc1cafbb1917 = L.marker(
#                 [37.5338727, 126.8292625],
#                 {
# }
#             ).addTo(map_2724366050a47a7261bcc106a4b84fbc);
#
#
#         var popup_77072b5768c05c5fb865ec16229f7020 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca83e7118da27c8f1bce68711ea8f267 = $(`&lt;div id=&quot;html_ca83e7118da27c8f1bce68711ea8f267&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;현대주유소&lt;/div&gt;`)[0];
#                 popup_77072b5768c05c5fb865ec16229f7020.setContent(html_ca83e7118da27c8f1bce68711ea8f267);
#
#
#
#         marker_0a6e0b2270bb9bd047ccdc1cafbb1917.bindPopup(popup_77072b5768c05c5fb865ec16229f7020)
#         ;
#
#
#
#
#             var marker_1b37aeb01ee6a91db6ffbe250d6d9018 = L.marker(
#                 [37.5407186, 126.8415303],

# %% [markdown]
# ---

# %% [markdown]
# 편의점이 있는 주유소들도 골라서 지도에 찍어보기

# %%
df_cvs = df[df['편의점']==True]
df_cvs = df_cvs[['주유소명','편의점','위도','경도']]

# %%
df_cvs
# Out:
#                       주유소명   편의점         위도          경도
# 37          (주)삼표에너지 고덕주유소  True  37.555049  127.129793
# 49          SK에너지(주) 매일주유소  True  37.622798  127.019136
# 55             행촌에너지 공항주유소  True  37.574611  126.802303
# 60                  뉴신정주유소  True  37.531580  126.856052
# 62           ㈜한경에너지 신화곡주유소  True  37.527258  126.842890
# 66                  스카이주유소  True  37.571486  126.804381
# 67          KH에너지㈜직영 가양주유소  True  37.569782  126.841902
# 68       KH에너지㈜직영 KH외발산주유소  True  37.543421  126.816863
# 72          대성석유(주)방화대성주유소  True  37.572882  126.823482
# 82                  박물관주유소  True  37.565785  126.845122
# 92       SK에너지(주)직영 신봉천주유소  True  37.478757  126.958343
# 125                  구인주유소  True  37.504278  126.886094
# 129                  동아주유소  True  37.490851  126.893188
# 134         대득에너지(금천셀프주유소)  True  37.441280  126.902925
# 203            SK에너지 양지주유소  True  37.537700  126.946403
# 207           (주)가재울뉴타운주유소  True  37.573267  126.922432
# 213            중앙에너비스 동교지점  True  37.558701  126.934214
# 214                행촌제2주유소  True  37.564220  126.944310
# 217                  연희주유소  True  37.569286  126.932531
# 218               만남의광장주유소  True  37.460084  127.042169
# 234           대성석유(주)연일주유소  True  37.482587  127.018513
# 242           대신석유(주)대우주유소  True  37.462831  127.037558
# 245        지에스칼텍스(주)남서울주유소  True  37.516157  127.018914
# 312               백제고분로주유소  True  37.512233  127.116877
# 319  HD현대오일뱅크㈜직영 남부순환셀프주유소  True  37.519492  126.838803
# 328                 신정동주유소  True  37.506554  126.871154
# 344                  행촌주유소  True  37.508616  126.906237
# 359         SK에너지(주) 기린주유소  True  37.536044  126.899268
# 365         SJ오일(주) 여의도주유소  True  37.530380  126.925578
# 368            (주)영원 풍기주유소  True  37.535617  126.962700

# %%
mapping = folium.Map(location=[df_cvs['위도'].iloc[3], df_cvs['경도'].iloc[3]], zoom_start=11)
for idx, row in df_cvs.iterrows():
    if row['위도'] == np.nan or row['경도'] == np.nan:
        continue
    else:
        folium.Marker([row['위도'], row['경도']], popup=row['주유소명']).add_to(mapping) 
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fc8bfa5dbc43bc94a0a39189da08018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fc8bfa5dbc43bc94a0a39189da08018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fc8bfa5dbc43bc94a0a39189da08018 = L.map(
#                 &quot;map_7fc8bfa5dbc43bc94a0a39189da08018&quot;,
#                 {
#                     center: [37.5315796, 126.8560524],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1303614c148f73484bf0324ed0d7d059 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1303614c148f73484bf0324ed0d7d059.addTo(map_7fc8bfa5dbc43bc94a0a39189da08018);
#
#
#             var marker_7eaf651772f18549f4ef7cee5e690909 = L.marker(
#                 [37.555049, 127.1297929],
#                 {
# }
#             ).addTo(map_7fc8bfa5dbc43bc94a0a39189da08018);
#
#
#         var popup_b92f3e3957bcb0d24fc57da91be16678 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a0714c0b7c793c4ebfb402709e055bf = $(`&lt;div id=&quot;html_5a0714c0b7c793c4ebfb402709e055bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)삼표에너지 고덕주유소&lt;/div&gt;`)[0];
#                 popup_b92f3e3957bcb0d24fc57da91be16678.setContent(html_5a0714c0b7c793c4ebfb402709e055bf);
#
#
#
#         marker_7eaf651772f18549f4ef7cee5e690909.bindPopup(popup_b92f3e3957bcb0d24fc57da91be16678)
#         ;
#
#
#
#
#             var marker_92852976d2ffba698cd663f35186913f = L.marker(
#                 [37.6227977, 127.0191356],
#                 {
# }
#             ).addTo(map_7fc8bfa5dbc43bc94a0a39189da08018);
#
#
#         var popup_8de6b6d5a3427f74fd84b4a8c28f98ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f96c1190c673d0e8c6e8a796c7f94a8 = $(`&lt;div id=&quot;html_8f96c1190c673d0e8c6e8a796c7f94a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SK에너지(주) 매일주유소&lt;/div&gt;`)[0];
#                 popup_8de6b6d5a3427f74fd84b4a8c28f98ed.setContent(html_8f96c1190c673d0e8c6e8a796c7f94a8);
#
#
#
#         marker_92852976d2ffba698cd663f35186913f.bindPopup(popup_8de6b6d5a3427f74fd84b4a8c28f98ed)
#         ;
#
#
#
#
#             var marker_587ab033f2222ea81f6253b3cfda73c1 = L.marker(
#                 [37.574611, 126.8023029],
#                 {
# }
#             ).addTo(map_7fc8bfa5dbc43bc94a0a39189da08018);
#
#
#         var popup_d8898c38dead82fa602709c6fb2df43e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e91df936ff34dd759c301b8dd84d0ce = $(`&lt;div id=&quot;html_2e91df936ff34dd759c301b8dd84d0ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;행촌에너지 공항주유소&lt;/div&gt;`)[0];
#                 popup_d8898c38dead82fa602709c6fb2df43e.setContent(html_2e91df936ff34dd759c301b8dd84d0ce);
#
#
#
#         marker_587ab033f2222ea81f6253b3cfda73c1.bindPopup(popup_d8898c38dead82fa602709c6fb2df43e)
#         ;
#
#
#
#
#             var marker_426ec614545cff6f73e72be9d1e7f21d = L.marker(
#                 [37.5315796, 126.8560524],
#                 {
# }
#             ).addTo(map_7fc8bfa5dbc43bc94a0a39189da08018);
#
#
#         var popup_68703665b795dfefec267aa43c3b6300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_870bb5fde4091273c3ad367cd8c192e3 = $(`&lt;div id=&quot;html_870bb5fde4091273c3ad367cd8c192e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;뉴신정주유소&lt;/div&gt;`)[0];
#                 popup_68703665b795dfefec267aa43c3b6300.setContent(html_870bb5fde4091273c3ad367cd8c192e3);
#
#
#
#         marker_426ec614545cff6f73e72be9d1e7f21d.bindPopup(popup_68703665b795dfefec267aa43c3b6300)
#         ;
#
#
#
#
#             var marker_7bb8f4e8372f96ee426ea96c17a11785 = L.marker(
#                 [37.5272579, 126.8428896],
#                 {
# }
#             ).addTo(map_7fc8bfa5dbc43bc94a0a39189da08018);
#
#
#         var popup_91a4ebef03f8ad4e46ac30f3d43261ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43bf6bf4ef3d6ea32867dc8157fb423c = $(`&lt;div id=&quot;html_43bf6bf4ef3d6ea32867dc8157fb423c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;㈜한경에너지 신화곡주유소&lt;/div&gt;`)[0];
#                 popup_91a4ebef03f8ad4e46ac30f3d43261ce.setContent(html_43bf6bf4ef3d6ea32867dc8157fb423c);
#
#
#
#         marker_7bb8f4e8372f96ee426ea96c17a11785.bindPopup(popup_91a4ebef03f8ad4e46ac30f3d43261ce)
#         ;
#
#
#
#
#             var marker_fc28dc58dc1bafc616e73d8493072f9e = L.marker(
#                 [37.5714858, 126.8043806],

# %% [markdown]
# ---

# %% [markdown]
# 보통휘발유 가격, 고급휘발유 가격, 경유 가격, 등유 가격 상관관계

# %%
price_table = df[['주유소명','보통휘발유 가격','고급휘발유 가격', '경유 가격', '실내 등유 가격']].set_index('주유소명')

# %%
price_table
# Out:
#                      보통휘발유 가격  고급휘발유 가격  경유 가격  실내 등유 가격
# 주유소명
# HD현대오일뱅크㈜직영 강남셀프주유소      1719    1899.0   1638       NaN
# HD현대오일뱅크㈜직영 강남셀프주유소      1719    1899.0   1699       NaN
# (주)보성 세곡주유소              1728    1928.0   1589       NaN
# (주)보성 세곡주유소              1737    1928.0   1609       NaN
# 오일프러스 셀프                 1739    1899.0   1638       NaN
# ...                       ...       ...    ...       ...
# (주)태영 구도일주유소 한인          1687    1877.0   1567       NaN
# 범아주유소                    1729       NaN   1589    1600.0
# 신내주유소                    1739       NaN   1598    1500.0
# 용마로주유소                   1758       NaN   1658    1600.0
# 신일셀프주유소                  1798       NaN   1698    1590.0
#
# [422 rows x 4 columns]

# %% [markdown]
# 보통휘발유와 다른 유종의 가격들 사이에는 강한 상관관계가 있다.

# %%
price_table.corr()
# Out:
#           보통휘발유 가격  고급휘발유 가격     경유 가격  실내 등유 가격
# 보통휘발유 가격  1.000000  0.959803  0.987753  0.759051
# 고급휘발유 가격  0.959803  1.000000  0.952841  0.835318
# 경유 가격     0.987753  0.952841  1.000000  0.778096
# 실내 등유 가격  0.759051  0.835318  0.778096  1.000000

# %%
plt.scatter(x=price_table['보통휘발유 가격'], y=price_table['고급휘발유 가격'], label="고급휘발유")
plt.scatter(x=price_table['보통휘발유 가격'], y=price_table['경유 가격'], color='purple', label='경유')
plt.scatter(x=price_table['보통휘발유 가격'], y=price_table['실내 등유 가격'], color='green', label='실내 등유')
plt.xlabel("보통휘발유 가격")
plt.ylabel('가격')
plt.legend()
plt.show()
